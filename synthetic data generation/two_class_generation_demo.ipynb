# %% [markdown]
# # This notebooks demonstrates three types of synthetic data in a simple-to-complex order.

# %%
from two_class_data_generation import *
import matplotlib.pyplot as plt
# %pylab inline
figsize(10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/ruslanhalitov/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
def plot(data, style='.'):
    for i in range(4):
        plt.subplot(2, 2, i + 1)
        plt.plot(data[i], style)
        if i<2:
            plt.title("Class 0")
        else:
            plt.title("Class 1")
        plt.ylim(data.min()-.3, data.max()+.3)
    plt.tight_layout()    
    
def plot_more(data, labels, style='.'):
    for i in range(len(data)):
        plt.subplot(len(data) // 2, len(data) // 2, i + 1)
        figsize(10, 12)
        plt.plot(data[i], style)
        plt.title("Class {}".format(int(labels[i])))
        plt.ylim(data.min()-.3, data.max()+.3)
    plt.tight_layout()

# %% [markdown]
# # 1 Binary
# ## 1.1 Simplest case: same sigma

# %%
data, class_labels = generate_two_class_data(4, 128, binary=True, same_sigma=True)

# %%
plot_more(data, class_labels)

# %%
class_labels
# Out:
# tensor([0., 0., 1., 1.])

# %% [markdown]
# ## 1.2 A bit more difficult: different sigmas

# %%
data, class_labels = generate_two_class_data(4, 128, binary=True, same_sigma=False)

# %%
plot(data)

# %% [markdown]
# # 1.3 XOR, different sigmas

# %%
data, class_labels = generate_two_class_data(4, 128, binary=True, same_sigma=False, xor=True)

# %%
plot(data)

# %% [markdown]
# # 2 Curve
# ## 2.1 Simplest curve data, same sigma

# %%
data, class_labels = generate_two_class_data(4, 128, binary=False, same_sigma=True)

# %%
plot(data, '-')

# %% [markdown]
# ## 2.2 Curve, different sigmas

# %%
data, class_labels = generate_two_class_data(16, 128, binary=False, same_sigma=False, xor=True)

# %%
plot_more(data, class_labels, '-')

# %% [markdown]
# ## 2.3 Curve, XOR, different sigmas

# %%
data, class_labels = generate_two_class_data(4, 128, binary=False, same_sigma=False, xor=True)

# %%
plot(data, '-')

# %% [markdown]
# # 3 Mixing data
# ## 3.1 Curve, same sigma, mixing

# %%
data, class_labels, data_orig, interaction, mixing = generate_two_class_mixed_data(4, 128, binary=False, same_sigma=True)

# %%
plot(data_orig, '-')

# %%
plot(data, '-')

# %% [markdown]
# ## 3.2 Curve, mixing, different sigmas, XOR

# %%
data, class_labels, data_orig, interaction, mixing = generate_two_class_mixed_data(4, 128, binary=False, same_sigma=False, xor=True)

# %%
plot(data_orig, '-')

# %%
plot(data, '-')

# %%
data, class_labels = generate_n_gaussians(12, 1024, 3)

# %%
plot_more(data, class_labels,  '-')

# %% [markdown]
# # 4 To do: use more complicated noise, for example,
# ## 4.1 periodical noise (e.g. +sin or +cos)
# ## 4.2 non-additive noise (e.g. multiplicative noise)
# ## 4.3 varying noise level within a sequence
